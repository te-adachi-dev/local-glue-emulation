# %%
# SparkSessionの作成
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session

# Hiveテーブルからデータを読み込む
df = spark.sql("SELECT * FROM test_db_20250407.can_data_ex")
df.printSchema()
df.show(5, truncate=False)

# データの基本的な操作
from pyspark.sql.functions import col, explode, from_json
from pyspark.sql.types import *

# JSON文字列からデータを抽出するサンプル
# metadataカラムをJSONとしてパース
schema = StructType([
    StructField("model", StringType(), True),
    StructField("driver_id", StringType(), True),
    StructField("scenario", StringType(), True)
])

# JSONカラムを展開
df_expanded = df.withColumn("metadata_json", from_json(col("metadata"), schema)) \
                .select("video_id", "vin", "metadata_json.*", "recording_duration")

df_expanded.show()

# 結果をCSVとして保存
df_expanded.write.mode("overwrite").csv("/home/glue_user/output/expanded_data.csv", header=True)
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/home/glue_user/spark/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/home/glue_user/spark/jars/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/home/glue_user/aws-glue-libs/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/home/glue_user/aws-glue-libs/jars/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /home/glue_user/spark/python/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 25/04/26 17:42:45 INFO HiveConf: Found configuration file file:/home/glue_user/spark/conf/hive-site.xml
# 25/04/26 17:42:46 ERROR HiveUtils: Unable to instantiate a metastore client factory  due to: java.lang.ClassNotFoundException: Class  not found
# java.lang.ClassNotFoundException: Class  not found
# 	at org.apache.hadoop.conf.Configuration.getClassByName(Configuration.java:2592)
# 	at org.apache.hadoop.hive.ql.metadata.HiveUtils.createMetaStoreClientFactory(HiveUtils.java:517)
# 	at org.apache.hadoop.hive.ql.metadata.HiveUtils.createMetaStoreClient(HiveUtils.java:506)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.getMSC(Hive.java:3856)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.getMSC(Hive.java:3836)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.getDatabase(Hive.java:1605)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.databaseExists(Hive.java:1594)
# 	at org.apache.spark.sql.hive.client.Shim_v0_12.databaseExists(HiveShim.scala:615)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$databaseExists$1(HiveClientImpl.scala:394)
# 	at scala.runtime.java8.JFunction0$mcZ$sp.apply(JFunction0$mcZ$sp.java:23)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$withHiveState$1(HiveClientImpl.scala:294)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.liftedTree1$1(HiveClientImpl.scala:225)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.retryLocked(HiveClientImpl.scala:224)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.withHiveState(HiveClientImpl.scala:274)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.databaseExists(HiveClientImpl.scala:394)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.$anonfun$databaseExists$1(HiveExternalCatalog.scala:248)
# 	at scala.runtime.java8.JFunction0$mcZ$sp.apply(JFunction0$mcZ$sp.java:23)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.withClient(HiveExternalCatalog.scala:104)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.databaseExists(HiveExternalCatalog.scala:248)
# 	at org.apache.spark.sql.internal.SharedState.externalCatalog$lzycompute(SharedState.scala:151)
# 	at org.apache.spark.sql.internal.SharedState.externalCatalog(SharedState.scala:141)
# 	at org.apache.spark.sql.internal.SharedState.isDatabaseExistent$1(SharedState.scala:185)
# 	at org.apache.spark.sql.internal.SharedState.globalTempViewManager$lzycompute(SharedState.scala:217)
# 	at org.apache.spark.sql.internal.SharedState.globalTempViewManager(SharedState.scala:169)
# 	at org.apache.spark.sql.hive.HiveSessionStateBuilder.$anonfun$catalog$2(HiveSessionStateBuilder.scala:62)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.globalTempViewManager$lzycompute(SessionCatalog.scala:122)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.globalTempViewManager(SessionCatalog.scala:122)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.lookupGlobalTempView(SessionCatalog.scala:949)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.lookupTempView(Analyzer.scala:1112)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.org$apache$spark$sql$catalyst$analysis$Analyzer$ResolveRelations$$lookupRelation(Analyzer.scala:1196)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$$anonfun$apply$13.applyOrElse(Analyzer.scala:1068)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$$anonfun$apply$13.applyOrElse(Analyzer.scala:1032)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$3(AnalysisHelper.scala:138)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:177)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$1(AnalysisHelper.scala:138)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:323)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning(AnalysisHelper.scala:134)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning$(AnalysisHelper.scala:130)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.resolveOperatorsUpWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$2(AnalysisHelper.scala:135)
# 	at org.apache.spark.sql.catalyst.trees.UnaryLike.mapChildren(TreeNode.scala:1249)
# 	at org.apache.spark.sql.catalyst.trees.UnaryLike.mapChildren$(TreeNode.scala:1248)
# 	at org.apache.spark.sql.catalyst.plans.logical.OrderPreservingUnaryNode.mapChildren(LogicalPlan.scala:226)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$1(AnalysisHelper.scala:135)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:323)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning(AnalysisHelper.scala:134)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning$(AnalysisHelper.scala:130)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.resolveOperatorsUpWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.apply(Analyzer.scala:1032)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.apply(Analyzer.scala:991)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$1(RuleExecutor.scala:215)
# 	at scala.collection.LinearSeqOptimized.foldLeft(LinearSeqOptimized.scala:126)
# 	at scala.collection.LinearSeqOptimized.foldLeft$(LinearSeqOptimized.scala:122)
# 	at scala.collection.immutable.List.foldLeft(List.scala:91)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.executeBatch$1(RuleExecutor.scala:212)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$6(RuleExecutor.scala:284)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor$RuleExecutionContext$.withContext(RuleExecutor.scala:327)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$5(RuleExecutor.scala:284)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$5$adapted(RuleExecutor.scala:274)
# 	at scala.collection.immutable.List.foreach(List.scala:431)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.execute(RuleExecutor.scala:274)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.execute(RuleExecutor.scala:188)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.org$apache$spark$sql$catalyst$analysis$Analyzer$$executeSameContext(Analyzer.scala:227)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$execute$1(Analyzer.scala:223)
# 	at org.apache.spark.sql.catalyst.analysis.AnalysisContext$.withNewAnalysisContext(Analyzer.scala:172)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.execute(Analyzer.scala:223)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.execute(Analyzer.scala:187)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$executeAndTrack$1(RuleExecutor.scala:179)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:107)
# 	at org.apache.spark.sql.catalyst.rules.RuleExecutor.executeAndTrack(RuleExecutor.scala:179)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:208)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:330)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:207)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$analyzed$1(QueryExecution.scala:78)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:192)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:213)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:552)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:213)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:212)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed$lzycompute(QueryExecution.scala:78)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:76)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:68)
# 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:101)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:99)
# 	at org.apache.spark.sql.SparkSession.$anonfun$sql$1(SparkSession.scala:622)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:617)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:750)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 spark = glueContext.spark_session
#      10 # Hiveテーブルからデータを読み込む
# ---> 11 df = spark.sql("SELECT * FROM test_db_20250407.can_data_ex")
#      12 df.printSchema()
#      13 df.show(5, truncate=False)
#
# File ~/spark/python/pyspark/sql/session.py:1034, in SparkSession.sql(self, sqlQuery, **kwargs)
#    1032     sqlQuery = formatter.format(sqlQuery, **kwargs)
#    1033 try:
# -> 1034     return DataFrame(self._jsparkSession.sql(sqlQuery), self)
#    1035 finally:
#    1036     if len(kwargs) > 0:
#
# File ~/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File ~/spark/python/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     192 converted = convert_exception(e.java_exception)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#     198     raise
#
# AnalysisException: org.apache.hadoop.hive.ql.metadata.HiveException: MetaException(message:Unable to instantiate a metastore client factory  due to: java.lang.ClassNotFoundException: Class  not found)

# %%
# スパークの設定でHiveメタストアの接続情報を指定
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("GlueLocal") \
    .config("spark.sql.warehouse.dir", "/tmp/hive/warehouse") \
    .config("hive.metastore.uris", "thrift://hive_metastore_20250407:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# テストクエリ
try:
    # データベース一覧を表示
    spark.sql("SHOW DATABASES").show()
    
    # test_db_20250407が存在するか確認
    dbs = [row[0] for row in spark.sql("SHOW DATABASES").collect()]
    if "test_db_20250407" in dbs:
        print("テストデータベースが見つかりました")
        # テーブル一覧を表示
        spark.sql("SHOW TABLES IN test_db_20250407").show()
    else:
        print("テストデータベースが見つかりません")
        
except Exception as e:
    print("エラーが発生しました:", e)
# Out:
# 25/04/26 17:43:30 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 25/04/26 17:43:33 INFO HiveConf: Found configuration file file:/home/glue_user/spark/conf/hive-site.xml
# 25/04/26 17:43:33 ERROR HiveUtils: Unable to instantiate a metastore client factory  due to: java.lang.ClassNotFoundException: Class  not found
# java.lang.ClassNotFoundException: Class  not found
# 	at org.apache.hadoop.conf.Configuration.getClassByName(Configuration.java:2592)
# 	at org.apache.hadoop.hive.ql.metadata.HiveUtils.createMetaStoreClientFactory(HiveUtils.java:517)
# 	at org.apache.hadoop.hive.ql.metadata.HiveUtils.createMetaStoreClient(HiveUtils.java:506)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.getMSC(Hive.java:3856)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.getMSC(Hive.java:3836)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.getDatabase(Hive.java:1605)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.databaseExists(Hive.java:1594)
# 	at org.apache.spark.sql.hive.client.Shim_v0_12.databaseExists(HiveShim.scala:615)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$databaseExists$1(HiveClientImpl.scala:394)
# 	at scala.runtime.java8.JFunction0$mcZ$sp.apply(JFunction0$mcZ$sp.java:23)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$withHiveState$1(HiveClientImpl.scala:294)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.liftedTree1$1(HiveClientImpl.scala:225)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.retryLocked(HiveClientImpl.scala:224)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.withHiveState(HiveClientImpl.scala:274)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.databaseExists(HiveClientImpl.scala:394)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.$anonfun$databaseExists$1(HiveExternalCatalog.scala:248)
# 	at scala.runtime.java8.JFunction0$mcZ$sp.apply(JFunction0$mcZ$sp.java:23)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.withClient(HiveExternalCatalog.scala:104)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.databaseExists(HiveExternalCatalog.scala:248)
# 	at org.apache.spark.sql.internal.SharedState.externalCatalog$lzycompute(SharedState.scala:151)
# 	at org.apache.spark.sql.internal.SharedState.externalCatalog(SharedState.scala:141)
# 	at org.apache.spark.sql.hive.HiveSessionStateBuilder.externalCatalog(HiveSessionStateBuilder.scala:54)
# 	at org.apache.spark.sql.hive.HiveSessionStateBuilder.$anonfun$catalog$1(HiveSessionStateBuilder.scala:61)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.externalCatalog$lzycompute(SessionCatalog.scala:121)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.externalCatalog(SessionCatalog.scala:121)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.listDatabases(SessionCatalog.scala:294)
# 	at org.apache.spark.sql.execution.datasources.v2.V2SessionCatalog.listNamespaces(V2SessionCatalog.scala:230)
# 	at org.apache.spark.sql.execution.datasources.v2.ShowNamespacesExec.run(ShowNamespacesExec.scala:42)
# 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.result$lzycompute(V2CommandExec.scala:43)
# 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.result(V2CommandExec.scala:43)
# 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.executeCollect(V2CommandExec.scala:49)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.$anonfun$applyOrElse$1(QueryExecution.scala:103)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:107)
# 	at org.apache.spark.sql.execution.SQLExecution$.withTracker(SQLExecution.scala:224)
# 	at org.apache.spark.sql.execution.SQLExecution$.executeQuery$1(SQLExecution.scala:114)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$7(SQLExecution.scala:139)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:107)
# 	at org.apache.spark.sql.execution.SQLExecution$.withTracker(SQLExecution.scala:224)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$6(SQLExecution.scala:139)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:245)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$1(SQLExecution.scala:138)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:68)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:100)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:96)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:615)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:177)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:615)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:267)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:263)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:30)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:591)
# 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:96)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted$lzycompute(QueryExecution.scala:83)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:81)
# 	at org.apache.spark.sql.Dataset.<init>(Dataset.scala:222)
# 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:102)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:99)
# 	at org.apache.spark.sql.SparkSession.$anonfun$sql$1(SparkSession.scala:622)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:779)
# 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:617)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:750)
# エラーが発生しました: An error occurred while calling o65.toString. Trace:
# java.lang.IllegalArgumentException: object is not an instance of declaring class
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:750)

# %%
# SparkSessionの作成（シンプルなもの）
from pyspark.context import SparkContext
from awsglue.context import GlueContext

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session

# CSVファイルを直接読み込む
try:
    # CSVファイルの場所を探す
    import subprocess
    result = subprocess.run(["find", "/home/glue_user", "-name", "*.csv"], capture_output=True, text=True)
    print("見つかったCSVファイル:")
    print(result.stdout)
    
    # 見つかったファイルのパスを使用してCSVを読み込む
    # 例として、先ほど作成したcan_data_exのパスを推測
    csv_path = "/home/glue_user/warehouse/test_db_20250407.db/can_data_ex"  # 推測したパス
    
    # 他の可能性のあるパス
    alternative_paths = [
        "/home/glue_user/data/input/csv/can_data_ex.csv",
        "/data/input/csv/can_data_ex.csv",
        "/opt/glue/data/can_data_ex.csv"
    ]
    
    # まずメインのパスを試す
    try:
        df = spark.read.csv(csv_path, header=True, inferSchema=True)
        print("メインパスからCSVを読み込みました")
        df.printSchema()
        df.show(5, truncate=False)
    except:
        print(f"{csv_path}からの読み込みに失敗しました。代替パスを試します...")
        
        # 代替パスを試す
        for path in alternative_paths:
            try:
                df = spark.read.csv(path, header=True, inferSchema=True)
                print(f"{path}からCSVを読み込みました")
                df.printSchema()
                df.show(5, truncate=False)
                break
            except:
                print(f"{path}からの読み込みに失敗しました")
        
except Exception as e:
    print("エラー発生:", e)
# Out:
# 見つかったCSVファイル:
# /home/glue_user/column_mappings/input_ap_mapping.csv
# /home/glue_user/column_mappings/master_device_attribute_mapping.csv
# /home/glue_user/column_mappings/can_data_ex_mapping.csv
# /home/glue_user/column_mappings/master_status_mapping.csv
# /home/glue_user/column_mappings/can_data_mapping.csv
# /home/glue_user/column_mappings/master_user_attribute_mapping.csv
# /home/glue_user/column_mappings/input_connection_mapping.csv
# /home/glue_user/column_mappings/extended_can_data.xlsx_mapping.csv
# /home/glue_user/spark/python/test_support/sql/ages_newlines.csv
# /home/glue_user/spark/python/test_support/sql/ages.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-log10.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-log2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-log.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-expm1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-exp2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-arctanh.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-cbrt.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-cos.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-tan.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-sin.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-arcsin.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-tanh.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-sinh.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-cosh.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-arcsinh.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-arccos.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-arctan.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-arccosh.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-log1p.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/core/tests/data/umath-validation-set-exp.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/mt19937-testset-2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/pcg64-testset-2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/philox-testset-1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/mt19937-testset-1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/pcg64-testset-1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/pcg64dxsm-testset-2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/sfc64-testset-2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/pcg64dxsm-testset-1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/sfc64-testset-1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/numpy/random/tests/data/philox-testset-2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/tornado/test/csv_translations/fr_FR.csv
# /home/glue_user/.local/lib/python3.10/site-packages/sklearn/datasets/data/boston_house_prices.csv
# /home/glue_user/.local/lib/python3.10/site-packages/sklearn/datasets/data/iris.csv
# /home/glue_user/.local/lib/python3.10/site-packages/sklearn/datasets/data/linnerud_exercise.csv
# /home/glue_user/.local/lib/python3.10/site-packages/sklearn/datasets/data/linnerud_physiological.csv
# /home/glue_user/.local/lib/python3.10/site-packages/sklearn/datasets/data/wine_data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/sklearn/datasets/data/breast_cancer.csv
# /home/glue_user/.local/lib/python3.10/site-packages/matplotlib/mpl-data/sample_data/data_x_x2_x3.csv
# /home/glue_user/.local/lib/python3.10/site-packages/matplotlib/mpl-data/sample_data/percent_bachelors_degrees_women_usa.csv
# /home/glue_user/.local/lib/python3.10/site-packages/matplotlib/mpl-data/sample_data/msft.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme06.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme07.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme05.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/theil_textile_predict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme03.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme00.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lasso_data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme04.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme02.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/results_rls_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme08.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme01.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme10.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme09.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/lme11.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/dietox.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/results_rls_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/regression/tests/results/pastes.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/miscmodels/tests/results/ologit_ucla.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/results_kde_weights.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/test_lowess_simple.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/results_kernel_regression.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/test_lowess_frac.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/results_kde_fft.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/test_lowess_iter.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/results_kde_univ_weights.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/results_kcde.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/results_kde.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/nonparametric/tests/results/test_lowess_delta.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/autos_predict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/prediction_from_mgcv.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/autos.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/gam_PIRLS_results.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/motorcycle.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/cubic_cyclic_splines_from_mgcv.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/autos_exog.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/gam/tests/results/logit_gam_mgcv.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/yhat_exact_c.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/stl_test_results.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/AROLSNoConstantPredict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arma_forecasts.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_forecasts_all_mle.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_exog_forecasts_css.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/stkprc.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/resids_css_nc.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/ARMLEConstantPredict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/rand10000.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/y_arma_data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/gnpdef.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/arima212_forecast.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/yhat_css_c.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/resids_exact_nc.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/resids_exact_c.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_corrgram.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/rgnp.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/stl_co2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/rgnpq.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/yhat_exact_nc.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_forecasts.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_ar_forecast_mle_dynamic.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/bds_results.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_exog_forecasts_mle.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/yhat_css_nc.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/resids_css_c.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_forecasts_all_css_diff.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/arima111_forecasts.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/AROLSConstantPredict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/bds_data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_forecasts_all_mle_diff.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/tests/results/results_arima_forecasts_all_css.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/tests/Matlab_results/test_coint.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/holtwinters/tests/results/housing-data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_clark1989_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/frbny_nowcast/Nowcasting/data/US/2016-06-29.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/frbny_nowcast/Nowcasting/data/US/2016-07-29.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing3_variates.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_dynamic_factor_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_Si0.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_Omega_22.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_intercepts_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_smoothing_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_posterior_mean.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/exponential_smoothing_states.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_beta.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing4.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_Omega_11.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_var1_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing5.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_v10.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing0.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_local_linear_trend_missing_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing3.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_state_variates.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_smoothing3_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/exponential_smoothing_params.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_var1_missing_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_local_linear_trend_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/exponential_smoothing_predict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_common_level_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_local_level_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_smoothing2_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_S10.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_realgdpar_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_wpi1_ar3_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_dfm_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_var1_measurement_error_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_var_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/clark1989.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_vi0.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_wpi1_ar3_matlab_ssm.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/cfa_tvpvar_invP.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_varmax_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_common_level_restricted_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_wpi1_missing_ar3_matlab_ssm.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_simulation_smoothing6.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_exact_initial_var1_mixed_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_var_R_output.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_smoothing_generalobscov_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/statespace/tests/results/results_sarimax_coverage.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/regime_switching/tests/results/results_predict_rgnp.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/regime_switching/tests/results/mar_filardo.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/tsa/regime_switching/tests/results/results_predict_fedfunds.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/results_influence_logit.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/binary_constrict.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/wspec3.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/influence_measures_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/contingency_table_r_results.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/wspec2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/bootleg.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/wspec1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/influence_measures_bool_R.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/wspec4.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/stats/tests/results/framing.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/sandbox/regression/tests/racd10data_with_transformed.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/ccard/ccard.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/fair/fair_pt.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/fair/fair.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/stackloss/stackloss.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/china_smoking/china_smoking.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/spector/spector.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/cpunish/cpunish.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/danish_data/data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/engel/engel.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/strikes/strikes.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/sunspots/sunspots.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/fertility/fertility.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/star98/star98.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/grunfeld/grunfeld.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/longley/longley.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/interest_inflation/E6.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/interest_inflation/E6_jmulti.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/elec_equip/elec_equip.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/anes96/anes96.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/elnino/elnino.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/randhie/randhie.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/heart/heart.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/cancer/cancer.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/nile/nile.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/macrodata/macrodata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/statecrime/statecrime.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/scotland/scotvote.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/modechoice/modechoice.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/committee/committee.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/co2/co2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/datasets/copper/copper.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/yhat_mnlogit.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/nbinom_resids.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/sm3533.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/mnlogit_resid.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/yhat_poisson.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/ships.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/predict_prob_poisson.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/poisson_resid.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/discrete/tests/results/phat_mnlogit.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/multivariate/tests/results/factor_data.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/multivariate/tests/results/factors_stata.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/othermod/tests/results/resid_methylation.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/othermod/tests/results/methylation-test.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/othermod/tests/results/foodexpenditure.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/survival_data_50_2.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/bmt_results.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/survival_data_20_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/survival_data_1000_10.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/survival_data_100_5.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/bmt.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/duration/tests/results/survival_data_50_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/stata_medpar1_glm.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/gee_logistic_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/gee_ordinal_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/iris.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/gee_linear_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/gee_nested_linear_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/epil.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/igaussident_resids.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/enet_binomial.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/gee_poisson_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/medparlogresids.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/enet_poisson.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/stata_lbw_glm.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/stata_cancer_glm.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/inv_gaussian.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/results_tweedie_aweights_nonrobust.csv
# /home/glue_user/.local/lib/python3.10/site-packages/statsmodels/genmod/tests/results/gee_nominal_1.csv
# /home/glue_user/.local/lib/python3.10/site-packages/pmdarima/arima/tests/data/issue_191.csv
# /home/glue_user/workspace/data/warehouse/input_connection/input_connection.csv
# /home/glue_user/workspace/data/warehouse/can_data_ex/can_data_ex.csv
# /home/glue_user/workspace/data/warehouse/master_device_attribute/master_device_attribute.csv
# /home/glue_user/workspace/data/warehouse/can_data/can_data.csv
# /home/glue_user/workspace/data/warehouse/input_ap/input_ap.csv
# /home/glue_user/workspace/data/warehouse/extended_can_data.xlsx/extended_can_data.xlsx.csv
# /home/glue_user/workspace/data/warehouse/master_user_attribute/master_user_attribute.csv
# /home/glue_user/workspace/data/warehouse/master_status/master_status.csv
# /home/glue_user/workspace/data/input/csv/can_data_ex.csv
# /home/glue_user/workspace/data/input/csv/master_status.csv
# /home/glue_user/workspace/data/input/csv/master_device_attribute.csv
# /home/glue_user/workspace/data/input/csv/input_connection.csv
# /home/glue_user/workspace/data/input/csv/input_ap.csv
# /home/glue_user/workspace/data/input/csv/master_user_attribute.csv
# /home/glue_user/workspace/data/master/status/master_status.csv
# /home/glue_user/workspace/data/master/user_attribute/master_user_attribute.csv
# /home/glue_user/workspace/data/master/device_attribute/master_device_attribute.csv
# /home/glue_user/workspace/hive-data/warehouse/input_connection/input_connection.csv
# /home/glue_user/workspace/hive-data/warehouse/can_data_ex/can_data_ex.csv
# /home/glue_user/workspace/hive-data/warehouse/master_device_attribute/master_device_attribute.csv
# /home/glue_user/workspace/hive-data/warehouse/can_data/can_data.csv
# /home/glue_user/workspace/hive-data/warehouse/input_ap/input_ap.csv
# /home/glue_user/workspace/hive-data/warehouse/extended_can_data.xlsx/extended_can_data.xlsx.csv
# /home/glue_user/workspace/hive-data/warehouse/master_user_attribute/master_user_attribute.csv
# /home/glue_user/workspace/hive-data/warehouse/master_status/master_status.csv
# /home/glue_user/workspace/crawler/column_mappings/input_ap_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/master_device_attribute_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/can_data_ex_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/master_status_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/can_data_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/master_user_attribute_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/input_connection_mapping.csv
# /home/glue_user/workspace/crawler/column_mappings/extended_can_data.xlsx_mapping.csv
#
# /home/glue_user/warehouse/test_db_20250407.db/can_data_exからの読み込みに失敗しました。代替パスを試します...
# /home/glue_user/data/input/csv/can_data_ex.csvからの読み込みに失敗しました
# /data/input/csv/can_data_ex.csvからの読み込みに失敗しました
# /opt/glue/data/can_data_ex.csvからの読み込みに失敗しました

# %%
# データを直接定義する方法
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
import json

# スキーマ定義
schema = StructType([
    StructField("video_id", StringType(), True),
    StructField("vin", StringType(), True),
    StructField("metadata", StringType(), True),
    StructField("recording_duration", DoubleType(), True),
    StructField("start_datetime", StringType(), True),
    StructField("end_datetime", StringType(), True),
    StructField("url", StringType(), True),
    StructField("thumbnail", StringType(), True),
    StructField("labels", StringType(), True),
    StructField("can_data", StringType(), True)
])

# サンプルデータ
data = [
    ["VID20250301001", "JH4DB7550SS801338", json.dumps({"model": "TestCar A", "driver_id": "D001", "scenario": "city_driving"}), 300.5, "2025-03-01T09:30:00", "2025-03-01T09:35:00", "https://test-storage.example.com/videos/20250301001.mp4", "https://test-storage.example.com/thumbnails/20250301001.jpg", json.dumps([{"label_id": "L0001", "frame_number": 120, "class_id": "car", "bbox": [100, 200, 150, 300], "score": 0.95}]), json.dumps([{"senddate": "2025-03-01T09:30:10", "candata": [{"speed": "45", "brake": "0", "steering": "5"}]}])],
    
    ["VID20250301002", "5UXWX7C5XEL982401", json.dumps({"model": "TestCar B", "driver_id": "D002", "scenario": "highway"}), 180.2, "2025-03-01T10:15:00", "2025-03-01T10:18:00", "https://test-storage.example.com/videos/20250301002.mp4", "https://test-storage.example.com/thumbnails/20250301002.jpg", json.dumps([{"label_id": "L0003", "frame_number": 45, "class_id": "car", "bbox": [200, 150, 300, 200], "score": 0.98}]), json.dumps([{"senddate": "2025-03-01T10:15:30", "candata": [{"speed": "95", "brake": "0", "steering": "2"}]}])]
]

# データフレーム作成
df = spark.createDataFrame(data, schema)
df.printSchema()
df.show(truncate=False)

# JSONフィールドを展開したデータ分析の例
from pyspark.sql.functions import col, from_json
import pyspark.sql.functions as F

# メタデータの展開
metadata_schema = StructType([
    StructField("model", StringType(), True),
    StructField("driver_id", StringType(), True),
    StructField("scenario", StringType(), True)
])

# メタデータを展開したデータフレーム
df_expanded = df.withColumn("metadata_json", from_json(col("metadata"), metadata_schema)) \
                .select("video_id", "vin", "metadata_json.*", "recording_duration")

print("メタデータを展開した結果:")
df_expanded.show(truncate=False)

# 車種と走行シナリオの集計例
print("シナリオ別の録画時間合計:")
df_expanded.groupBy("scenario").agg(F.sum("recording_duration").alias("total_duration")).show()

print("車種別の録画件数:")
df_expanded.groupBy("model").count().show()
# Out:
# root
#  |-- video_id: string (nullable = true)
#  |-- vin: string (nullable = true)
#  |-- metadata: string (nullable = true)
#  |-- recording_duration: double (nullable = true)
#  |-- start_datetime: string (nullable = true)
#  |-- end_datetime: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- thumbnail: string (nullable = true)
#  |-- labels: string (nullable = true)
#  |-- can_data: string (nullable = true)
# +--------------+-----------------+-----------------------------------------------------------------------+------------------+-------------------+-------------------+-------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+
# |video_id      |vin              |metadata                                                               |recording_duration|start_datetime     |end_datetime       |url                                                    |thumbnail                                                  |labels                                                                                                      |can_data                                                                                          |
# +--------------+-----------------+-----------------------------------------------------------------------+------------------+-------------------+-------------------+-------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+
# |VID20250301001|JH4DB7550SS801338|{"model": "TestCar A", "driver_id": "D001", "scenario": "city_driving"}|300.5             |2025-03-01T09:30:00|2025-03-01T09:35:00|https://test-storage.example.com/videos/20250301001.mp4|https://test-storage.example.com/thumbnails/20250301001.jpg|[{"label_id": "L0001", "frame_number": 120, "class_id": "car", "bbox": [100, 200, 150, 300], "score": 0.95}]|[{"senddate": "2025-03-01T09:30:10", "candata": [{"speed": "45", "brake": "0", "steering": "5"}]}]|
# |VID20250301002|5UXWX7C5XEL982401|{"model": "TestCar B", "driver_id": "D002", "scenario": "highway"}     |180.2             |2025-03-01T10:15:00|2025-03-01T10:18:00|https://test-storage.example.com/videos/20250301002.mp4|https://test-storage.example.com/thumbnails/20250301002.jpg|[{"label_id": "L0003", "frame_number": 45, "class_id": "car", "bbox": [200, 150, 300, 200], "score": 0.98}] |[{"senddate": "2025-03-01T10:15:30", "candata": [{"speed": "95", "brake": "0", "steering": "2"}]}]|
# +--------------+-----------------+-----------------------------------------------------------------------+------------------+-------------------+-------------------+-------------------------------------------------------+-----------------------------------------------------------+------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+
#
# メタデータを展開した結果:
# +--------------+-----------------+---------+---------+------------+------------------+
# |video_id      |vin              |model    |driver_id|scenario    |recording_duration|
# +--------------+-----------------+---------+---------+------------+------------------+
# |VID20250301001|JH4DB7550SS801338|TestCar A|D001     |city_driving|300.5             |
# |VID20250301002|5UXWX7C5XEL982401|TestCar B|D002     |highway     |180.2             |
# +--------------+-----------------+---------+---------+------------+------------------+
#
# シナリオ別の録画時間合計:
# +------------+--------------+
# |    scenario|total_duration|
# +------------+--------------+
# |city_driving|         300.5|
# |     highway|         180.2|
# +------------+--------------+
#
# 車種別の録画件数:
# +---------+-----+
# |    model|count|
# +---------+-----+
# |TestCar A|    1|
# |TestCar B|    1|
# +---------+-----+
